# %%
import janitor
import pandas as pd
import ydata_profiling as yp

# %%
ames_df = pd.read_csv('data/AmesHousing.csv')
ames_df = ames_df.clean_names(remove_special=True)

# %%
ames_df.to_csv('data/data.csv', index=False)
display(ames_df)
# Out:
#       order        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 0         1  526301100           20        RL         141.0     31770   Pave
# 1         2  526350040           20        RH          80.0     11622   Pave
# 2         3  526351010           20        RL          81.0     14267   Pave
# 3         4  526353030           20        RL          93.0     11160   Pave
# 4         5  527105010           60        RL          74.0     13830   Pave
# ...     ...        ...          ...       ...           ...       ...    ...
# 2925   2926  923275080           80        RL          37.0      7937   Pave
# 2926   2927  923276100           20        RL           NaN      8885   Pave
# 2927   2928  923400125           85        RL          62.0     10441   Pave
# 2928   2929  924100070           20        RL          77.0     10010   Pave
# 2929   2930  924151050           60        RL          74.0      9627   Pave
#
#      alley lot_shape land_contour  ... pool_area pool_qc  fence misc_feature  \
# 0      NaN       IR1          Lvl  ...         0     NaN    NaN          NaN
# 1      NaN       Reg          Lvl  ...         0     NaN  MnPrv          NaN
# 2      NaN       IR1          Lvl  ...         0     NaN    NaN         Gar2
# 3      NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 4      NaN       IR1          Lvl  ...         0     NaN  MnPrv          NaN
# ...    ...       ...          ...  ...       ...     ...    ...          ...
# 2925   NaN       IR1          Lvl  ...         0     NaN  GdPrv          NaN
# 2926   NaN       IR1          Low  ...         0     NaN  MnPrv          NaN
# 2927   NaN       Reg          Lvl  ...         0     NaN  MnPrv         Shed
# 2928   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
# 2929   NaN       Reg          Lvl  ...         0     NaN    NaN          NaN
#
#      misc_val mo_sold yr_sold sale_type  sale_condition  saleprice
# 0           0       5    2010       WD           Normal     215000
# 1           0       6    2010       WD           Normal     105000
# 2       12500       6    2010       WD           Normal     172000
# 3           0       4    2010       WD           Normal     244000
# 4           0       3    2010       WD           Normal     189900
# ...       ...     ...     ...       ...             ...        ...
# 2925        0       3    2006       WD           Normal     142500
# 2926        0       6    2006       WD           Normal     131000
# 2927      700       7    2006       WD           Normal     132000
# 2928        0       4    2006       WD           Normal     170000
# 2929        0      11    2006       WD           Normal     188000
#
# [2930 rows x 82 columns]

# %%
profile = yp.ProfileReport(ames_df)
profile.to_notebook_iframe()
profile.to_file('eda_report.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 2
#       1 profile = yp.ProfileReport(ames_df)
# ----> 2 profile.to_notebook_iframe()
#       3 profile.to_file('eda_report.html')
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\profile_report.py:521, in ProfileReport.to_notebook_iframe(self)
#     519 with warnings.catch_warnings():
#     520     warnings.simplefilter("ignore")
# --> 521     display(get_notebook_iframe(self.config, self))
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:75, in get_notebook_iframe(config, profile)
#      73     output = get_notebook_iframe_src(config, profile)
#      74 elif attribute == IframeAttribute.srcdoc:
# ---> 75     output = get_notebook_iframe_srcdoc(config, profile)
#      76 else:
#      77     raise ValueError(
#      78         f'Iframe Attribute can be "src" or "srcdoc" (current: {attribute}).'
#      79     )
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\report\presentation\flavours\widget\notebook.py:29, in get_notebook_iframe_srcdoc(config, profile)
#      27 width = config.notebook.iframe.width
#      28 height = config.notebook.iframe.height
# ---> 29 src = html.escape(profile.to_html())
#      31 iframe = f'<iframe width="{width}" height="{height}" srcdoc="{src}" frameborder="0" allowfullscreen></iframe>'
#      33 return HTML(iframe)
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\profile_report.py:491, in ProfileReport.to_html(self)
#     483 def to_html(self) -> str:
#     484     """Generate and return complete template as lengthy string
#     485         for using with frameworks.
#     486
#    (...)
#     489
#     490     """
# --> 491     return self.html
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\profile_report.py:287, in ProfileReport.html(self)
#     284 @property
#     285 def html(self) -> str:
#     286     if self._html is None:
# --> 287         self._html = self._render_html()
#     288     return self._html
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\profile_report.py:404, in ProfileReport._render_html(self)
#     401 def _render_html(self) -> str:
#     402     from ydata_profiling.report.presentation.flavours import HTMLReport
# --> 404     report = self.report
#     406     with tqdm(
#     407         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     408     ) as pbar:
#     409         html = HTMLReport(copy.deepcopy(report)).render(
#     410             nav=self.config.html.navbar_show,
#     411             offline=self.config.html.use_local_assets,
#    (...)
#     419             version=self.description_set.package["ydata_profiling_version"],
#     420         )
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\profile_report.py:281, in ProfileReport.report(self)
#     278 @property
#     279 def report(self) -> Root:
#     280     if self._report is None:
# --> 281         self._report = get_report_structure(self.config, self.description_set)
#     282     return self._report
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\profile_report.py:263, in ProfileReport.description_set(self)
#     260 @property
#     261 def description_set(self) -> BaseDescription:
#     262     if self._description_set is None:
# --> 263         self._description_set = describe_df(
#     264             self.config,
#     265             self.df,
#     266             self.summarizer,
#     267             self.typeset,
#     268             self._sample,
#     269         )
#     270     return self._description_set
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\model\describe.py:130, in describe(config, df, summarizer, typeset, sample)
#     126 scatter_matrix: Dict[Any, Dict[Any, Any]] = {
#     127     x: {y: None} for x, y in scatter_tasks
#     128 }
#     129 for x, y in scatter_tasks:
# --> 130     scatter_matrix[x][y] = progress(
#     131         get_scatter_plot, pbar, f"scatter {x}, {y}"
#     132     )(config, df, x, y, interval_columns)
#     134 # missing diagrams
#     135 missing_map = get_missing_active(config, table_stats)
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\utils\progress_bar.py:11, in progress.<locals>.inner(*args, **kwargs)
#       8 @wraps(fn)
#       9 def inner(*args, **kwargs) -> Any:
#      10     bar.set_postfix_str(message)
# ---> 11     ret = fn(*args, **kwargs)
#      12     bar.update()
#      13     return ret
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\model\pairwise.py:31, in get_scatter_plot(config, df, x, y, continuous_variables)
#      29     else:
#      30         df_temp = df[[x, y]].dropna()
# ---> 31     return scatter_pairwise(config, df_temp[x], df_temp[y], x, y)
#      32 else:
#      33     return ""
#
# File ~\anaconda3\envs\ons_eval\Lib\contextlib.py:81, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      78 @wraps(func)
#      79 def inner(*args, **kwds):
#      80     with self._recreate_cm():
# ---> 81         return func(*args, **kwds)
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\visualisation\plot.py:374, in scatter_pairwise(config, series1, series2, x_label, y_label)
#     372 else:
#     373     plt.scatter(series1[indices], series2[indices], color=color)
# --> 374 return plot_360_n0sc0pe(config)
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\ydata_profiling\visualisation\utils.py:73, in plot_360_n0sc0pe(config, image_format, bbox_extra_artists, bbox_inches)
#      70 if image_format == "svg":
#      71     image_str = StringIO()
# ---> 73     plt.savefig(
#      74         image_str,
#      75         format=image_format,
#      76         bbox_extra_artists=bbox_extra_artists,
#      77         bbox_inches=bbox_inches,
#      78     )
#      79     plt.close()
#      80     result_string = image_str.getvalue()
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\pyplot.py:1228, in savefig(*args, **kwargs)
#    1225 fig = gcf()
#    1226 # savefig default implementation has no return, so mypy is unhappy
#    1227 # presumably this is here because subclasses can return?
# -> 1228 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1229 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
#    1230 return res
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\figure.py:3395, in Figure.savefig(self, fname, transparent, **kwargs)
#    3393     for ax in self.axes:
#    3394         _recursively_make_axes_transparent(stack, ax)
# -> 3395 self.canvas.print_figure(fname, **kwargs)
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\backend_bases.py:2204, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2200 try:
#    2201     # _get_renderer may change the figure dpi (as vector formats
#    2202     # force the figure dpi to 72), so we need to set it again here.
#    2203     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2204         result = print_method(
#    2205             filename,
#    2206             facecolor=facecolor,
#    2207             edgecolor=edgecolor,
#    2208             orientation=orientation,
#    2209             bbox_inches_restore=_bbox_inches_restore,
#    2210             **kwargs)
#    2211 finally:
#    2212     if bbox_inches and restore_bbox:
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\backend_bases.py:2054, in FigureCanvasBase._switch_canvas_and_return_print_method.<locals>.<lambda>(*args, **kwargs)
#    2050     optional_kws = {  # Passed by print_figure for other renderers.
#    2051         "dpi", "facecolor", "edgecolor", "orientation",
#    2052         "bbox_inches_restore"}
#    2053     skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2054     print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2055         *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2056 else:  # Let third-parties do as they see fit.
#    2057     print_method = meth
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\backends\backend_svg.py:1339, in FigureCanvasSVG.print_svg(self, filename, bbox_inches_restore, metadata)
#    1334 w, h = width * 72, height * 72
#    1335 renderer = MixedModeRenderer(
#    1336     self.figure, width, height, dpi,
#    1337     RendererSVG(w, h, fh, image_dpi=dpi, metadata=metadata),
#    1338     bbox_inches_restore=bbox_inches_restore)
# -> 1339 self.figure.draw(renderer)
#    1340 renderer.finalize()
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\figure.py:3162, in Figure.draw(self, renderer)
#    3159             # ValueError can occur when resizing a window.
#    3161     self.patch.draw(renderer)
# -> 3162     mimage._draw_list_compositing_images(
#    3163         renderer, self, artists, self.suppressComposite)
#    3165     renderer.close_group('figure')
#    3166 finally:
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\axes\_base.py:3137, in _AxesBase.draw(self, renderer)
#    3134 if artists_rasterized:
#    3135     _draw_rasterized(self.figure, artists_rasterized, renderer)
# -> 3137 mimage._draw_list_compositing_images(
#    3138     renderer, self, artists, self.figure.suppressComposite)
#    3140 renderer.close_group('axes')
#    3141 self.stale = False
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\axis.py:1427, in Axis.draw(self, renderer)
#    1424 tlb1, tlb2 = self._get_ticklabel_bboxes(ticks_to_draw, renderer)
#    1426 for tick in ticks_to_draw:
# -> 1427     tick.draw(renderer)
#    1429 # Shift label away from axes to avoid overlapping ticklabels.
#    1430 self._update_label_position(renderer)
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\axis.py:277, in Tick.draw(self, renderer)
#     274 renderer.open_group(self.__name__, gid=self.get_gid())
#     275 for artist in [self.gridline, self.tick1line, self.tick2line,
#     276                self.label1, self.label2]:
# --> 277     artist.draw(renderer)
#     278 renderer.close_group(self.__name__)
#     279 self.stale = False
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\text.py:800, in Text.draw(self, renderer)
#     796             textrenderer.draw_tex(gc, x, y, clean_line,
#     797                                   self._fontproperties, angle,
#     798                                   mtext=mtext)
#     799         else:
# --> 800             textrenderer.draw_text(gc, x, y, clean_line,
#     801                                    self._fontproperties, angle,
#     802                                    ismath=ismath, mtext=mtext)
#     804 gc.restore()
#     805 renderer.close_group('text')
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\backends\backend_svg.py:1267, in RendererSVG.draw_text(self, gc, x, y, s, prop, angle, ismath, mtext)
#    1264     self.writer.start('a', {'xlink:href': gc.get_url()})
#    1266 if mpl.rcParams['svg.fonttype'] == 'path':
# -> 1267     self._draw_text_as_path(gc, x, y, s, prop, angle, ismath, mtext)
#    1268 else:
#    1269     self._draw_text_as_text(gc, x, y, s, prop, angle, ismath, mtext)
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\backends\backend_svg.py:1047, in RendererSVG._draw_text_as_path(self, gc, x, y, s, prop, angle, ismath, mtext)
#    1045 if not ismath:
#    1046     font = text2path._get_font(prop)
# -> 1047     _glyphs = text2path.get_glyphs_with_font(
#    1048         font, s, glyph_map=glyph_map, return_new_glyphs_only=True)
#    1049     glyph_info, glyph_map_new, rects = _glyphs
#    1050     self._update_glyph_map_defs(glyph_map_new)
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\textpath.py:148, in TextToPath.get_glyphs_with_font(self, font, s, glyph_map, return_new_glyphs_only)
#     146 xpositions = []
#     147 glyph_ids = []
# --> 148 for item in _text_helpers.layout(s, font):
#     149     char_id = self._get_char_id(item.ft_object, ord(item.char))
#     150     glyph_ids.append(char_id)
#
# File ~\anaconda3\envs\ons_eval\Lib\site-packages\matplotlib\_text_helpers.py:79, in layout(string, font, kern_mode)
#      74 kern = (
#      75     base_font.get_kerning(prev_glyph_idx, glyph_idx, kern_mode) / 64
#      76     if prev_glyph_idx is not None else 0.
#      77 )
#      78 x += kern
# ---> 79 glyph = font.load_glyph(glyph_idx, flags=LOAD_NO_HINTING)
#      80 yield LayoutItem(font, char, glyph_idx, x, kern)
#      81 x += glyph.linearHoriAdvance / 65536
#
# KeyboardInterrupt:
